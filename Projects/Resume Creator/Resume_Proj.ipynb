# %%
# Importing library
import qrcode
#Ask for user input
data = input("Enter the URL you want to encode: ")
# Data to be encoded
#data = 'https://nicholasstull.com'
 
# Encoding data using make() function
img = qrcode.make(data)
 
# Saving as an image file
img.save('ekresumecode.png')

# %%
import re

# Text Variables
Header = '>>>This resume was generated entirely in Python. For full sourcecode, view my portfolio.'
#ask user for name and title
Name = input("Enter your name: ")
Title = input("Enter your title: ")
# ask user for contact info
City = input("Enter your City, State: ")
Phone = input("Enter your phone number: ")
# Remove non-numeric characters from the phone input
Phone = re.sub('[^0-9]', '', Phone)
# Format the phone number as (xxx) xxx-xxxx
Formatted_Phone = f"({Phone[:3]}) {Phone[3:6]}-{Phone[6:]}"
Email = input("Enter your email: ")
LinkedIn = input("Enter your LinkedIn Username: ")
LinkedIn = 'https://www.linkedin.com/in/' + LinkedIn
GitHub = input("Enter your GitHub Username: ")
GitHub = 'https://www.github.com/' + GitHub
Contact = City + '\n'+ Formatted_Phone + '\n' + Email + '\n' + LinkedIn +'\n' + GitHub
Portfolio = input("Enter your Portfolio URL: ")
Portfolio = 'Portfolio: ' + Portfolio
ProjectsHeader = 'PROJECTS/PUBLICATIONS'
Projectsnumber = ("What 3 Projects/Publications do you want to highlight?")
ProjectOneTitle = input("Enter Project One Title: ")
ProjectOneDesc = input("Enter Project One Description: ")
ProjectTwoTitle = input("Enter Project Two Title: ")
ProjectTwoDesc = input("Enter Project Two Description: ")
ProjectThreeTitle = input("Enter Project Three Title: ")
ProjectThreeDesc = input("Enter Project Three Description: ")
Portfolio = input("Enter your Portfolio URL: ")
Portfolio = 'Portfolio: ' + Portfolio
WorkHeader = 'EXPERIENCE'
WorkOneTitle = input("Enter Company One Title: ")
WorkOneTimeA = input("When did you start?")
WorkOneTimeB = input("When did you end?")
WorkOneDesc = '- Raised $350k in startup funds, recruited/organized launch team\n- Coordinated branding and communication strategy for organization\n- Led team of 80 volunteer and staff leaders'
WorkTwoTitle = 'Second Company / Second Position'
WorkTwoTime = '2/2007-8/2013'
WorkTwoDesc = '- Led team of over 100 full-time and contract staff\n- Helped create branding and messaging for weekly content\n- Created/directed musical elements at weekly events for up to 10,000 people'
WorkThreeTitle = 'Third Company / Third Position'
WorkThreeTime = '6/2004-2/2007'
WorkThreeDesc = '- Planned/Coordianted Toronto arena event and South Africa speaking tour\n- Oversaw research for published products'
EduHeader = 'EDUCATION'
EduOneTitle = 'Example University, Bachelor of Business Administration'
EduOneTime = '2000-2004'
EduOneDesc = '- Major: Management, Minor: Statistics'
EduTwoTitle = 'Example University, Master of Arts'
EduTwoTime = '2013-2017'
SkillsHeader = 'Skills'
SkillsDesc = '- Python\n- Panas\n- NumPy\n- Data Visualization\n- Data Cleaning\n- Command Line\n- Git and Version Control\n- SQL\n- APIs\n- Probability/Statistics\n- Data Manipulation\n- Excel'
ExtrasTitle = 'DataQuest\nData Scientist Path'
ExtrasDesc = 'Learned popular data science\nlanguages, data cleaning and\nmanipulation, machine learning \nand statistical analysis'
CodeTitle = 'View Portfolio'

# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

fig, ax = plt.subplots(figsize=(8.5, 11))

# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')

# add text
plt.annotate(Header, (.02,.98), weight='regular', fontsize=8, alpha=.6)
plt.annotate(Name, (.02,.94), weight='bold', fontsize=20)
plt.annotate(Title, (.02,.91), weight='regular', fontsize=14)
plt.annotate(Contact, (.7,.906), weight='regular', fontsize=8, color='#ffffff')
plt.annotate(ProjectsHeader, (.02,.86), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(ProjectOneTitle, (.02,.832), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.04,.78), weight='regular', fontsize=9)
plt.annotate(ProjectTwoTitle, (.02,.745), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.04,.71), weight='regular', fontsize=9)
plt.annotate(ProjectThreeTitle, (.02,.672), weight='bold', fontsize=10)
plt.annotate(ProjectThreeDesc, (.04,.638), weight='regular', fontsize=9)
plt.annotate(Portfolio, (.02,.6), weight='bold', fontsize=10)
plt.annotate(WorkHeader, (.02,.54), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(WorkOneTitle, (.02,.508), weight='bold', fontsize=10)
plt.annotate(WorkOneTime, (.02,.493), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkOneDesc, (.04,.445), weight='regular', fontsize=9)
plt.annotate(WorkTwoTitle, (.02,.4), weight='bold', fontsize=10)
plt.annotate(WorkTwoTime, (.02,.385), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkTwoDesc, (.04,.337), weight='regular', fontsize=9)
plt.annotate(WorkThreeTitle, (.02,.295), weight='bold', fontsize=10)
plt.annotate(WorkThreeTime, (.02,.28), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkThreeDesc, (.04,.247), weight='regular', fontsize=9)
plt.annotate(EduHeader, (.02,.185), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(EduOneTitle, (.02,.155), weight='bold', fontsize=10)
plt.annotate(EduOneTime, (.02,.14), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduOneDesc, (.04,.125), weight='regular', fontsize=9)
plt.annotate(EduTwoTitle, (.02,.08), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.02,.065), weight='regular', fontsize=9, alpha=.6)
plt.annotate(SkillsHeader, (.7,.8), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(SkillsDesc, (.7,.56), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(ExtrasTitle, (.7,.43), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(ExtrasDesc, (.7,.345), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(CodeTitle, (.7,.2), weight='bold', fontsize=10, color='#ffffff')

#add qr code
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg
arr_code = mpimg.imread('ekresumecode.png')
imagebox = OffsetImage(arr_code, zoom=0.5)
ab = AnnotationBbox(imagebox, (0.84, 0.12))
ax.add_artist(ab)

plt.savefig('resumeexample.png', dpi=300, bbox_inches='tight')

# %%
# Text Variables
Header = '>>>This resume was generated entirely in Python. For full sourcecode, view my portfolio.'
#ask user for name and title
Name = input("Enter your name: ")
Title = input("Enter your title: ")
# ask user for contact info
City = input("Enter your City, State: ")
Phone = input("Enter your phone number: ")
# Remove non-numeric characters from the phone input
Phone = re.sub('[^0-9]', '', Phone)
# Format the phone number as (xxx) xxx-xxxx
Formatted_Phone = f"({Phone[:3]}) {Phone[3:6]}-{Phone[6:]}"
Email = input("Enter your email: ")
LinkedIn = input("Enter your LinkedIn Username: ")
LinkedIn = 'https://www.linkedin.com/in/' + LinkedIn
GitHub = input("Enter your GitHub Username: ")
GitHub = 'https://www.github.com/' + GitHub
Contact = City + '\n'+ Formatted_Phone + '\n' + Email + '\n' + LinkedIn +'\n' + GitHub
Portfolio = input("Enter your Portfolio URL: ")
Portfolio = 'Portfolio: ' + Portfolio
ProjectsHeader = 'PROJECTS/PUBLICATIONS'
Projectsnumber = ("What 3 Projects/Publications do you want to highlight?")
ProjectOneTitle = input("Enter Project One Title: ")
ProjectOneDesc = input("Enter Project One Description: ")
ProjectTwoTitle = input("Enter Project Two Title: ")
ProjectTwoDesc = input("Enter Project Two Description: ")
ProjectThreeTitle = input("Enter Project Three Title: ")
ProjectThreeDesc = input("Enter Project Three Description: ")
WorkHeader = 'EXPERIENCE'
WorkOneTitle = input("Enter Company One Title: ")
WorkOneTimeA = input("When did you start?")
WorkOneTimeB = input("When did you end?")
WorkOneDesc = '- Raised $350k in startup funds, recruited/organized launch team\n- Coordinated branding and communication strategy for organization\n- Led team of 80 volunteer and staff leaders'
WorkTwoTitle = 'Second Company / Second Position'
WorkTwoTime = '2/2007-8/2013'
WorkTwoDesc = '- Led team of over 100 full-time and contract staff\n- Helped create branding and messaging for weekly content\n- Created/directed musical elements at weekly events for up to 10,000 people'
WorkThreeTitle = 'Third Company / Third Position'
WorkThreeTime = '6/2004-2/2007'
WorkThreeDesc = '- Planned/Coordianted Toronto arena event and South Africa speaking tour\n- Oversaw research for published products'
EduHeader = 'EDUCATION'
EduOneTitle = 'Example University, Bachelor of Business Administration'
EduOneTime = '2000-2004'
EduOneDesc = '- Major: Management, Minor: Statistics'
EduTwoTitle = 'Example University, Master of Arts'
EduTwoTime = '2013-2017'
SkillsHeader = 'Skills'
SkillsDesc = '- Python\n- Panas\n- NumPy\n- Data Visualization\n- Data Cleaning\n- Command Line\n- Git and Version Control\n- SQL\n- APIs\n- Probability/Statistics\n- Data Manipulation\n- Excel'
ExtrasTitle = 'DataQuest\nData Scientist Path'
ExtrasDesc = 'Learned popular data science\nlanguages, data cleaning and\nmanipulation, machine learning \nand statistical analysis'
CodeTitle = 'View Portfolio'

# %%
# Text Variables
Header = '>>>This resume was generated entirely in Python. For full sourcecode, view my portfolio.'
Name = 'NICHOLAS STULL'
Title = 'IT Technician'
Contact = 'Berrien Springs,MI\n269-487-7564\nNicholasp.stull@gmail.com\nlinkedin.com/in/ekirkland\ngithub.com/e-kirkland'
ProjectsHeader = 'PROJECTS/PUBLICATIONS'
ProjectOneTitle = 'Increasing Kaggle Revenue'
ProjectOneDesc = '- Published by Towards Data Science\n- Analyzed user survey to recommend most profitable future revenue source\n- Cleaned/visualized data using pandas/matplotlib libraries in Python'
ProjectTwoTitle = 'NYC School Data Cleaning & Analysis'
ProjectTwoDesc = '- Cleaned and combined several tables using pandas library in Python\n- Used PDE and visualization to determine correlations for future study'
ProjectThreeTitle = 'Pandas Cleaning and Visualization'
ProjectThreeDesc = '- Cleaned data for analysis using pandas library in Python\n- Used pandas and matplotlib to explore which cars hold the most value over time'
Portfolio = 'Portfolio: rebrand.ly/ekirkland'
WorkHeader = 'EXPERIENCE'
WorkOneTitle = 'Example Company / Example Position'
WorkOneTime = '8/2013-Present'
WorkOneDesc = '- Raised $350k in startup funds, recruited/organized launch team\n- Coordinated branding and communication strategy for organization\n- Led team of 80 volunteer and staff leaders'
WorkTwoTitle = 'Second Company / Second Position'
WorkTwoTime = '2/2007-8/2013'
WorkTwoDesc = '- Led team of over 100 full-time and contract staff\n- Helped create branding and messaging for weekly content\n- Created/directed musical elements at weekly events for up to 10,000 people'
WorkThreeTitle = 'Third Company / Third Position'
WorkThreeTime = '6/2004-2/2007'
WorkThreeDesc = '- Planned/Coordianted Toronto arena event and South Africa speaking tour\n- Oversaw research for published products'
EduHeader = 'EDUCATION'
EduOneTitle = 'Example University, Bachelor of Business Administration'
EduOneTime = '2000-2004'
EduOneDesc = '- Major: Management, Minor: Statistics'
EduTwoTitle = 'Example University, Master of Arts'
EduTwoTime = '2013-2017'
SkillsHeader = 'Skills'
SkillsDesc = '- Python\n- Panas\n- NumPy\n- Data Visualization\n- Data Cleaning\n- Command Line\n- Git and Version Control\n- SQL\n- APIs\n- Probability/Statistics\n- Data Manipulation\n- Excel'
ExtrasTitle = 'DataQuest\nData Scientist Path'
ExtrasDesc = 'Learned popular data science\nlanguages, data cleaning and\nmanipulation, machine learning \nand statistical analysis'
CodeTitle = 'View Portfolio'

# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

fig, ax = plt.subplots(figsize=(8.5, 11))

# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')

# add text
plt.annotate(Header, (.02,.98), weight='regular', fontsize=8, alpha=.6)
plt.annotate(Name, (.02,.94), weight='bold', fontsize=20)
plt.annotate(Title, (.02,.91), weight='regular', fontsize=14)
plt.annotate(Contact, (.7,.906), weight='regular', fontsize=8, color='#ffffff')
plt.annotate(ProjectsHeader, (.02,.86), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(ProjectOneTitle, (.02,.832), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.04,.78), weight='regular', fontsize=9)
plt.annotate(ProjectTwoTitle, (.02,.745), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.04,.71), weight='regular', fontsize=9)
plt.annotate(ProjectThreeTitle, (.02,.672), weight='bold', fontsize=10)
plt.annotate(ProjectThreeDesc, (.04,.638), weight='regular', fontsize=9)
plt.annotate(Portfolio, (.02,.6), weight='bold', fontsize=10)
plt.annotate(WorkHeader, (.02,.54), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(WorkOneTitle, (.02,.508), weight='bold', fontsize=10)
plt.annotate(WorkOneTime, (.02,.493), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkOneDesc, (.04,.445), weight='regular', fontsize=9)
plt.annotate(WorkTwoTitle, (.02,.4), weight='bold', fontsize=10)
plt.annotate(WorkTwoTime, (.02,.385), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkTwoDesc, (.04,.337), weight='regular', fontsize=9)
plt.annotate(WorkThreeTitle, (.02,.295), weight='bold', fontsize=10)
plt.annotate(WorkThreeTime, (.02,.28), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkThreeDesc, (.04,.247), weight='regular', fontsize=9)
plt.annotate(EduHeader, (.02,.185), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(EduOneTitle, (.02,.155), weight='bold', fontsize=10)
plt.annotate(EduOneTime, (.02,.14), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduOneDesc, (.04,.125), weight='regular', fontsize=9)
plt.annotate(EduTwoTitle, (.02,.08), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.02,.065), weight='regular', fontsize=9, alpha=.6)
plt.annotate(SkillsHeader, (.7,.8), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(SkillsDesc, (.7,.56), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(ExtrasTitle, (.7,.43), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(ExtrasDesc, (.7,.345), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(CodeTitle, (.7,.2), weight='bold', fontsize=10, color='#ffffff')

#add qr code
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg
arr_code = mpimg.imread('ekresumecode.png')
imagebox = OffsetImage(arr_code, zoom=0.5)
ab = AnnotationBbox(imagebox, (0.84, 0.12))
ax.add_artist(ab)

plt.savefig('resumeexample.png', dpi=300, bbox_inches='tight')

# %%
# Importing the necessary libraries
import docx

# Creating a new document
document = docx.Document()

# Adding heading to the document
document.add_heading('Resume', 0)

# Getting the user inputs
name = input('Enter your name: ')
email = input('Enter your email address: ')
phone = input('Enter your phone number: ')
address = input('Enter your address: ')
skills = input('Enter your skills (comma separated): ')
experience = input('Enter your experience: ')
education = input('Enter your education: ')

# Adding name to the document
document.add_heading('Name', level=1)
document.add_paragraph(name)

# Adding contact information to the document
document.add_heading('Contact Information', level=1)
document.add_paragraph(f'Email: {email}')
document.add_paragraph(f'Phone: {phone}')
document.add_paragraph(f'Address: {address}')

# Adding skills to the document
document.add_heading('Skills', level=1)
document.add_paragraph(skills)

# Adding experience to the document
document.add_heading('Experience', level=1)
document.add_paragraph(experience)

# Adding education to the document
document.add_heading('Education', level=1)
document.add_paragraph(education)

# Saving the document
document.save('Resume.docx')

# %%
from docx import Document
from docx.shared import Inches

#creating document object
document = Document()
#profile photo````
#document.add_picture('yourpic.jpg', width=Inches(1.0) )

#name and phone number 
print("Let's start with your contact information:")
fname = input('Please enter your first name: ').capitalize()
lname = input('Please enter your last name: ').capitalize()
phone = input('Please enter your phone number: ')
email = input('Please enter your email address: ')
document.add_paragraph(f"{fname} {lname} | {phone} | {email}")

#about me
document.add_heading('About me')
document.add_paragraph(input('Tell us a little about yourself: '))

#work experience
document.add_heading('Work Experience')
p = document.add_paragraph()

print("Let's gather your work experience:")
company = input('Please enter company name: ')
title = input('Please enter the title of your position at this job: ')
from_date = input('Date Started mm/dd/yyyy: ')
to_date = input('End Date mm/dd/yyyy: ')

company_name = p.add_run(company)
company_name.bold = True
company_name.underline = True
p.add_run(f' \n')

p.add_run(f'{title} \n').bold = True
p.add_run(f'{from_date} - {to_date} \n').italic = True

experience_details = input(f'Describe your job experience at {company}: ')
p.add_run(experience_details)

#more experiences
while True:
    has_more_experiences = input('Do you have any other experience? Yes or No: ')
    if has_more_experiences.lower() == 'yes':
        p = document.add_paragraph()
        company = input('Please enter company name: ')
        title = input('Please enter the title of your position at this job: ')
        from_date = input('Date Started mm/dd/yyyy: ')
        to_date = input('End Date mm/dd/yyyy: ')

        company_name = p.add_run(company)
        company_name.bold = True
        company_name.underline = True
        p.add_run(f' \n')

        p.add_run(f'{title} \n').bold = True
        p.add_run(f'{from_date} - {to_date} \n').italic = True

        experience_details = input(f'Describe your job experience at {company}: ')
        p.add_run(experience_details)
    else:
        break

#Credentials: Degrees & IT Certifications
#Skills


document.save('sample_resume_1.docx')
# Out:
# Let's start with your contact information:
# Let's gather your work experience:

# %%
from docx import Document
from docx.shared import Inches
import re

# creating document object
document = Document()

# profile photo
document.add_picture('yourpic.jpg', width=Inches(1.0))

# name and phone number
print("Let's start with your contact information:")
fname = input('Please enter your first name: ').capitalize()
lname = input('Please enter your last name: ').capitalize()
fone = input('Please enter your phone number: ')
fone = re.sub('[^0-9]', '', phone)
# Format the phone number as (xxx) xxx-xxxx
formatted_fone = f"({fone[:3]}) {fone[3:6]}-{fone[6:]}"
email = input('Please enter your email address: ').capitalize()
City = input("Enter your City, State: ")
City = ' '.join(elem.capitalize() for elem in City.split())
print(City)
document.add_paragraph(f"{fname} {lname} | {Formatted_Phone} | {email} | {City}")

# about me
document.add_heading('About me')
document.add_paragraph(input('Tell us a little about yourself: '))

# work experience
document.add_heading('Work Experience')
p = document.add_paragraph()

print("Let's gather your work experience:")
company = input('Please enter company name: ')
title = input('Please enter the title of your position at this job: ')
from_date = input('Date Started mm/dd/yyyy: ')
to_date = input('End Date mm/dd/yyyy: ')

company_name = p.add_run(company)
company_name.bold = True
company_name.underline = True
p.add_run(f' \n')

p.add_run(f'{title} \n').bold = True
p.add_run(f'{from_date} - {to_date} \n').italic = True

experience_details = input(f'Describe your job experience at {company}: ')
p.add_run(experience_details)

# more experiences
while True:
    has_more_experiences = input('Do you have any other experience? Yes or No: ')
    if has_more_experiences.lower() == 'yes':
        p = document.add_paragraph()
        company = input('Please enter company name: ')
        title = input('Please enter the title of your position at this job: ')
        from_date = input('Date Started mm/dd/yyyy: ')
        to_date = input('End Date mm/dd/yyyy: ')

        company_name = p.add_run(company)
        company_name.bold = True
        company_name.underline = True
        p.add_run(f' \n')

        p.add_run(f'{title} \n').bold = True
        p.add_run(f'{from_date} - {to_date} \n').italic = True

        experience_details = input(f'Describe your job experience at {company}: ')
        p.add_run(experience_details)
    else:
        break

# Credentials: Degrees & IT Certifications
document.add_heading('Credentials: Degrees & IT Certifications')
p = document.add_paragraph()
degree = input('Please enter your highest degree: ')
certification = input('Please enter your IT certification: ')
p.add_run(f'{degree} \n').bold = True
p.add_run(f'{certification} \n')

# Skills
document.add_heading('Skills')
skills = []
while len(skills) < 12:
    skills = input("Enter a skill (press enter to stop): ")
    if skills:
        skills.append(skills)
    else:
        break

skills_str = ",".join(skills)

document.save('sample_resume_1.docx')
# Out:
# Let's start with your contact information:
# Berrien Springs, Mi
# Let's gather your work experience:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 87
#      85 skills = input("Enter a skill (press enter to stop): ")
#      86 if skills:
# ---> 87     skills.append(skills)
#      88 else:
#      89     break
#
# AttributeError: 'str' object has no attribute 'append'

# %%
# Import necessary libraries
from docx import Document
from docx.shared import Pt
from docx.enum.text import WD_ALIGN_PARAGRAPH

# Create a new document
document = Document()

# Add heading
heading = document.add_heading('John Doe', 0)
heading.alignment = WD_ALIGN_PARAGRAPH.CENTER

# Add subheading
subheading = document.add_heading('Python Developer', 1)
subheading.alignment = WD_ALIGN_PARAGRAPH.CENTER

# Add contact details
contact_details = document.add_paragraph()
contact_details.add_run('123 Main Street, Anytown USA 12345 \n')
contact_details.add_run('555-555-5555 | john.doe@email.com \n')

# Add summary
summary_heading = document.add_heading('Summary', level=3)
summary = document.add_paragraph('Experienced Python developer with a strong background in web development and data analysis.')

# Add skills
skills_heading = document.add_heading('Skills', level=3)
skills = document.add_paragraph()
skills.add_run('Python\n').bold = True
skills.add_run('Web development\n')
skills.add_run('Data analysis\n')

# Add education
education_heading = document.add_heading('Education', level=3)
education = document.add_paragraph()
education.add_run('Bachelor of Science in Computer Science, XYZ University\n')
education.add_run('Graduated May 2020\n')

# Add work experience
experience_heading = document.add_heading('Work Experience', level=3)

# Job 1
job1 = document.add_paragraph()
job1.add_run('Python Developer, ABC Company\n').bold = True
job1.add_run('June 2020 - Present\n')
job1.add_run('- Developed and maintained web applications using Flask and Django\n')
job1.add_run('- Designed and implemented data models using SQLAlchemy\n')
job1.add_run('- Created automated scripts for data analysis and reporting using Pandas\n')

# Job 2
job2 = document.add_paragraph()
job2.add_run('Intern, DEF Company\n').bold = True
job2.add_run('May 2019 - August 2019\n')
job2.add_run('- Assisted with development of web applications using Flask\n')
job2.add_run('- Conducted research on data analysis techniques using Python\n')

# Save document
document.save('resume.docx')

# %%
import re 
Name = input("Enter your name: ")
Name = ' '.join(elem.capitalize() for elem in Name.split())
print(Name)

Title = input("Enter your title: ")
Title = ' '.join(elem.capitalize() for elem in Title.split())
print(Title)

# ask user for contact info
City = input("Enter your City, State: ")
City = ' '.join(elem.capitalize() for elem in City.split())
print(City)

Phone = input("Enter your phone number: ")
# Remove non-numeric characters from the phone input
Phone = re.sub('[^0-9]', '', Phone)
# Format the phone number as (xxx) xxx-xxxx
Formatted_Phone = f"({Phone[:3]}) {Phone[3:6]}-{Phone[6:]}"
print(Formatted_Phone)

Email = input("Enter your email: ")
Email = ' '.join(elem.capitalize() for elem in Email.split())
print(Email)

LinkedIn = input("Enter your LinkedIn Username: ")
LinkedIn = '-'.join(word[:1].upper() + word[1:] for word in LinkedIn.split('-'))
LinkedIn = 'https://www.linkedin.com/in/' + LinkedIn
print(LinkedIn)

GitHub = input("Enter your GitHub Username: ")
GitHub = '-'.join(word[:1].upper() + word[1:] for word in GitHub.split('-'))

GitHub = 'https://www.github.com/' + GitHub
print(GitHub)

Contact = City + '\n'+ Formatted_Phone + '\n' + Email + '\n' + LinkedIn +'\n' + GitHub

Portfolio = input("Enter your Portfolio URL: ").capitalize()
Portfolio = 'Portfolio: ' + Portfolio
print(Portfolio)

ProjectsHeader = 'PROJECTS/PUBLICATIONS'
print (ProjectsHeader)

# Projectsnumber = ("What 3 Projects/Publications do you want to highlight?")
# ProjectOneTitle = input("Enter Project One Title: ")
# ProjectOneDesc = input("Enter Project One Description: ")

# ProjectTwoTitle = input("Enter Project Two Title: ")
# ProjectTwoDesc = input("Enter Project Two Description: ")

# ProjectThreeTitle = input("Enter Project Three Title: ")
# ProjectThreeDesc = input("Enter Project Three Description: ")

# WorkHeader = 'EXPERIENCE'
# print(WorkHeader)

# WorkOneTitle = input("Enter Company One Title: ")
# WorkOneTimeA = input("When did you start?")
# WorkOneTimeB = input("When did you end?")
# WorkOneDesc = '- Raised $350k in startup funds, recruited/organized launch team\n- Coordinated branding and communication strategy for organization\n- Led team of 80 volunteer and staff leaders'

# WorkTwoTitle = 'Second Company / Second Position'
# WorkTwoTime = '2/2007-8/2013'
# WorkTwoDesc = '- Led team of over 100 full-time and contract staff\n- Helped create branding and messaging for weekly content\n- Created/directed musical elements at weekly events for up to 10,000 people'

# WorkThreeTitle = 'Third Company / Third Position'
# WorkThreeTime = '6/2004-2/2007'
# WorkThreeDesc = '- Planned/Coordianted Toronto arena event and South Africa speaking tour\n- Oversaw research for published products'

# EduHeader = 'EDUCATION'
# print(EduHeader)

# EduOneTitle = 'Example University, Bachelor of Business Administration'
# EduOneTime = '2000-2004'
# EduOneDesc = '- Major: Management, Minor: Statistics'

# EduTwoTitle = 'Example University, Master of Arts'
# EduTwoTime = '2013-2017'

SkillsHeader = 'Skills'
print(SkillsHeader)
skills = []
while len(skills) < 12:
    skill = input("Enter a skill (press enter to stop): ")
    if skill:
        skills.append(skill)
    else:
        break

skills_str = ",".join(skills)
print("Skills:")
print(skills_str)

# %%
from docx import Document
from docx.shared import Inches,Pt
import re,qrcode
from docx.enum.text import WD_ALIGN_PARAGRAPH


# creating document object
document = Document()
#Name
Name = input("Enter your name: ")
Name = ' '.join(elem.capitalize() for elem in Name.split())
Name_Heading = document.add_heading(Name,0)
Name_Heading.alignment = WD_ALIGN_PARAGRAPH.CENTER

#Add Title/Subheading
Title = input("Enter your title: ")
Title = ' '.join(elem.capitalize() for elem in Title.split())
Title_Heading = document.add_heading(Title,1)
Title_Heading.alignment = WD_ALIGN_PARAGRAPH.CENTER


# Add contact details
City = input("Enter your City, State: ")
City = ' '.join(elem.capitalize() for elem in City.split())

# Phone
Phone = input("Enter your phone number: ")
Phone = re.sub('[^0-9]', '', Phone)
Formatted_Phone = f"({Phone[:3]}) {Phone[3:6]}-{Phone[6:]}"

# Email
Email = input("Enter your email: ")
Email = ' '.join(elem.capitalize() for elem in Email.split())
# qr code
data = input("Enter the URL you want to encode: ")
img = qrcode.make(data)
img.save('qr.png')
qr_run = Name_Heading.add_run()
qr_run.add_picture('qr.png', width=Inches(1.0))
qr_run.alignment = WD_ALIGN_PARAGRAPH.RIGHT


contact_details = document.add_paragraph()
contact_details.add_run(City + '\n').bold = True
contact_details.add_run(Formatted_Phone + '\n').bold = True
contact_details.add_run(Email + '\n').bold = True
contact_details.alignment = WD_ALIGN_PARAGRAPH.CENTER


# about me
document.add_heading('About me')
document.add_paragraph(input('Tell us a little about yourself: '))

# work experience
document.add_heading('Work Experience')
p = document.add_paragraph()

print("Let's gather your work experience:")
company = input('Please enter company name: ')
title = input('Please enter the title of your position at this job: ')
from_date = input('Date Started mm/dd/yyyy: ')
to_date = input('End Date mm/dd/yyyy: ')

company_name = p.add_run(company)
company_name.bold = True
company_name.underline = True
p.add_run(f' \n')

p.add_run(f'{title} \n').bold = True
p.add_run(f'{from_date} - {to_date} \n').italic = True

experience_details = input(f'Describe your job experience at {company}: ')
p.add_run(experience_details)

# more experiences
while True:
    has_more_experiences = input('Do you have any other experience? Yes or No: ')
    if has_more_experiences.lower() == 'yes':
        p = document.add_paragraph()
        company = input('Please enter company name: ')
        title = input('Please enter the title of your position at this job: ')
        from_date = input('Date Started mm/dd/yyyy: ')
        to_date = input('End Date mm/dd/yyyy: ')

        company_name = p.add_run(company)
        company_name.bold = True
        company_name.underline = True
        p.add_run(f' \n')

        p.add_run(f'{title} \n').bold = True
        p.add_run(f'{from_date} - {to_date} \n').italic = True

        experience_details = input(f'Describe your job experience at {company}: ')
        p.add_run(experience_details)
    else:
        break

# Credentials: Degrees & IT Certifications
document.add_heading('Degrees',level=3)
p = document.add_paragraph()
degree = input('Please enter your highest degree: ')
document.add_paragraph(f'{degree} \n', style='List Bullet')
p.add_run(f'{degree} \n').bold = True

document.add_heading('Certifications')
p = document.add_paragraph()
certification = input('Please enter your IT certification: ')
p.add_run(f'{certification} \n').bold = True

# Skills
document.add_heading('Skills')
p = document.add_paragraph()
skills = []
while len(skills) < 12:
    skill = input("Enter a skill (press enter to add another): ")
    if skill:
        skills.append(skill)
    else:
        break
skills_list = document.add_paragraph(style='List Bullet')
for skill in skills:
    skills_list = document.add_paragraph(style='List Bullet')
    skills_list.add_run(skill)
docu_name = ('_'.join(elem.capitalize() for elem in Name.split()) + "_Resume.docx")
document.save(docu_name)

# %%
# Import necessary libraries
from docx import Document
from docx.shared import Pt
from docx.enum.text import WD_ALIGN_PARAGRAPH

# Create a new document
document = Document()



# Add contact details
contact_details = document.add_paragraph()
contact_details.add_run('123 Main Street, Anytown USA 12345 \n')
contact_details.add_run('555-555-5555 | john.doe@email.com \n')

# Add summary
summary_heading = document.add_heading('Summary', level=3)
summary = document.add_paragraph('Experienced Python developer with a strong background in web development and data analysis.')

# Add skills
skills_heading = document.add_heading('Skills', level=3)
skills = document.add_paragraph()
skills.add_run('Python\n').bold = True
skills.add_run('Web development\n')
skills.add_run('Data analysis\n')

# Add education
education_heading = document.add_heading('Education', level=3)
education = document.add_paragraph()
education.add_run('Bachelor of Science in Computer Science, XYZ University\n')
education.add_run('Graduated May 2020\n')

# Add work experience
experience_heading = document.add_heading('Work Experience', level=3)


# Save document
document.save('resume.docx')

# %%
from docx import Document
from docx.shared import Inches,Pt
import re,qrcode
from docx.enum.text import WD_ALIGN_PARAGRAPH

# creating document object
document = Document()

#name
name = input("Enter your name: ")
name = ' '.join(elem.capitalize() for elem in name.split())
name_heading = document.add_heading(name,0)
name_heading.alignment = WD_ALIGN_PARAGRAPH.CENTER

#job subheading
job = input("Enter your title: ")
job = ' '.join(elem.capitalize() for elem in job.split())
job_heading = document.add_heading(job,1)
job_heading.alignment = WD_ALIGN_PARAGRAPH.CENTER

#city and state
city = input("Enter your City, State: ")
city = ' '.join(elem.capitalize() for elem in city.split())

#phone
phone = input("Enter your phone number: ")
phone = re.sub('[^0-9]', '', phone)
formating_phone = f"({phone[:3]}) {phone[3:6]}-{phone[6:]}"

#email
email = input("Enter your email: ")
email = ' '.join(elem.capitalize() for elem in email.split())

#qr code
data = input("Enter the URL you want to encode to the qr code: ")
img = qrcode.make(data)
img.save('qr.png')

#contact details
contact_details = document.add_paragraph()
contact_details.add_run(city + '\n').bold = True
contact_details.add_run(formating_phone + '\n').bold = True
contact_details.add_run(email + '\n').bold = True
contact_details.alignment = WD_ALIGN_PARAGRAPH.CENTER

#summary
summary_heading = document.add_heading('Summary', level=3)
document.add_paragraph(input('Tell us a little about yourself: '))

# work experience
experience_heading = document.add_heading('Work Experience', level=3)
p = document.add_paragraph()
print("Let's gather your work experience:")
company = input('Please enter company name: ')
title = input('Please enter the title of your position at this job: ')
from_date = input('Date Started mm/dd/yyyy: ')
to_date = input('End Date mm/dd/yyyy: ')

company_name = p.add_run(company)
company_name.bold = True
company_name.underline = True
p.add_run(f' \n')

p.add_run(f'{title} \n').bold = True
p.add_run(f'{from_date} - {to_date} \n').italic = True

experience_details = input(f'Describe your job experience at {company}: ')
p.add_run(experience_details)

# more experiences
while True:
    has_more_experiences = input('Do you have any other experience? Yes or No: ')
    if has_more_experiences.lower() == 'yes':
        p = document.add_paragraph()
        company = input('Please enter company name: ')
        title = input('Please enter the title of your position at this job: ')
        from_date = input('Date Started mm/dd/yyyy: ')
        to_date = input('End Date mm/dd/yyyy: ')

        company_name = p.add_run(company)
        company_name.bold = True
        company_name.underline = True
        p.add_run(f' \n')

        p.add_run(f'{title} \n').bold = True
        p.add_run(f'{from_date} - {to_date} \n').italic = True

        experience_details = input(f'Describe your job experience at {company}: ')
        p.add_run(experience_details)
    else:
        break

# Credentials: Degrees & IT Certifications
# Add degrees
document.add_heading('Degrees',level=3)
p = document.add_paragraph()
degree = input('Please enter your highest degree: ')
place = input('Please enter the place of your degree: ')
from_date = input('Date recieved mm/dd/yyyy: ')
p.add_run(f'{degree} \n').bold = True
p.add_run(f'{place} \n').bold = True
p.add_run(f'{from_date} \n').italic = True
while True:
    has_more_degree = input('Do you have any other Degree? Yes or No: ')
    if has_more_degree.lower() == 'yes':
        p = document.add_paragraph()
        degree2 = input('Please enter degree: ')
        place2 = input('Please enter the place of your degree: ')
        from_date2 = input('Date recieved mm/dd/yyyy: ')
        p.add_run(f'{degree2} \n').bold = True
        p.add_run(f'{place2} \n').bold = True
        p.add_run(f'{from_date2} \n').italic = True
    else:
        break


# Add certifications
document.add_heading('Certifications',level=3)
p = document.add_paragraph()
certification = input('Please enter your IT certification: ')
p.add_run(f'{certification} \n').bold = True


# Skills
skills_heading = document.add_heading('Skills', level=3)
skills = document.add_paragraph()
skills = []
while len(skills) < 12:
    skill = input("Enter a skill (press enter to add another): ")
    if skill:
        skills.append(skill)
    else:
        break
skills_list = document.add_paragraph(style='List Bullet')
for skill in skills:
    skills_list = document.add_paragraph(style='List Bullet')
    skills_list.add_run(skill)
docu_name = ('_'.join(elem.capitalize() for elem in name.split()) + "_Resume.docx")
document.save(docu_name)
